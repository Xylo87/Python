# %%
l1 = [3, 6, 9, 12, 15, 18, 21]
l2 = [4, 8, 12, 16, 20, 24, 28]

newList = []

newList.extend(l1[1::2] + l2[0::2])

print(newList)

# %%
list1 = [54, 44, 27, 79, 91, 41]

def manipList(l):
    forth = l.pop(4)

    l.insert(2, forth)
    l.append(forth)

manipList(list1)
print(list1)

# %%
sample_list = [11, 45, 8, 23, 14, 12, 78, 45, 89]

# first = sample_list[:int(len(sample_list) / 3):]
# second = sample_list[int(len(sample_list) / 3):int(len(sample_list) / 3) * 2:]
# third = sample_list[int(len(sample_list) / 3) * 2::]

# print(first[::-1])
# print(second[::-1])
# print(third[::-1])

length = len(sample_list)
chunk_size = int(length / 3)
start = 0
end = chunk_size

for i in range(3):

    chunk = sample_list[start:end:]
    
    start = end
    end += chunk_size

    print(chunk[::-1])

# %%
sample_list = [11, 45, 8, 11, 23, 45, 23, 45, 89]
sample_dict = dict()

for num in sample_list:
    sample_dict[num] = sample_list.count(num)

print(sample_dict)

# %%
first_list = [2, 3, 4, 5, 6, 7, 8]
second_list = [4, 9, 16, 25, 36, 49, 64]

pack = zip(first_list, second_list)
print(set(pack))

# %%
first_set = {23, 42, 65, 57, 78, 83, 29}
second_set = {57, 83, 29, 67, 73, 43, 48}

inter = first_set.intersection(second_set)
finalDiff = first_set.difference(inter)

print(finalDiff)

# %%
first_set = {27, 43, 34}
second_set = {34, 93, 22, 27, 43, 53, 48}

if first_set.issubset(second_set) or first_set.issuperset(second_set):
    first_set.clear()

print(first_set)

# %%
roll_number = [47, 64, 69, 37, 76, 83, 95, 97]
sample_dict = {'Jhon':47, 'Emma':69, 'Kelly':76, 'Jason':97}

new_roll = [el for el in roll_number if el in sample_dict.values()]

print(new_roll)

# %%
speed = {'jan': 47, 'feb': 52, 'march': 47, 'April': 44, 'May': 52, 'June': 53, 'july': 54, 'Aug': 44, 'Sept': 54}

dupRem = list(set(speed.values()))
print(dupRem)

# %%
sample_list = [87, 45, 41, 65, 94, 41, 99, 94]

toTuple = tuple(set(sample_list))
minVal = min(toTuple)
maxVal = max(toTuple)

print(toTuple)
print(minVal)
print(maxVal)
