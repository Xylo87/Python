# %%
print('Hello')

# %%
import random


def get_choices():
    player_choice = input('Enter a choice (rock, paper, scissors) :')

    options = ['rock', 'paper', 'scissors']
    computer_choice = random.choice(options)

    choices = {"player" : player_choice, "computer": computer_choice}

    return choices


def check_win(player, computer):
    print(f'You chose {player}, computer chose {computer}.')

    if player == computer:
        return 'It\'s a tie !'
    # elif (player == 'rock' and computer == 'scissors') or (player == 'paper' and computer == 'rock') or (player == 'scissors' and computer == 'paper'):
    #     return 'You win !'
    elif player == 'rock':
        if computer == 'scissors':
            return 'Rock smashes scissors. You win !'
        else:
            return 'Paper covers rock. You lose !'
    elif player == 'paper':
        if computer == 'paper':
            return 'Paper covers rock. You win !'
        else:
            return 'Scissors cut paper. You lose !'
    elif player == 'scissors':
        if computer == 'paper':
            return 'Scissors cut paper. You win !'
        else:
            return 'Rock smashes scissors. You lose !'
    # else:
    #     return 'Computer wins !'

choices = get_choices()

result = check_win(choices['player'], choices['computer'])
print(result)

# %%
name = 'kiouze'
print(type(name))
print(isinstance(name, str))

age = float(2)
print(isinstance(age, float))

number = '20'
age2 = int(number)
print(isinstance(age2, int))

# %%
print("""Now I wanna
be your
dog.""")

print('BeE\nUwU.')

# %%
name = 'Xylo'

print(name[1])
print(name[2:4])

# %%
ingredients_purchased = True
meal_cooked = False

ready_to_serve = any([ingredients_purchased, meal_cooked])
print(ready_to_serve)

ready_to_serve2 = all([ingredients_purchased, meal_cooked])
print(ready_to_serve2)

# %%
# > Constantes creation

from enum import Enum

class State(Enum):
    INACTIVE = 0
    ACTIVE = 1

print(State.ACTIVE.value)
print(State(1))
print(list(State))
print(len(State))

# %%
# > "In" Method
dogs = ["Kazel", "Kiouze", 75, True, "Quincy"]
print("Kiouze" in dogs)

# > Negative Index
print(dogs[-1])

# > Slice Method
print(dogs[2:4])

# > Length Method
print(len(dogs))

# > Insert at Index
dogs[2] = "Blackmane"
print(dogs)

# > Insert at end
dogs.append("Judah")
print(dogs)

# > Array Fusion
dogs.extend(["Mewstelle", "MisterMV", "Dr. Pierre"])
# dogs += "Mewstelle", "MisterMV", "Dr. Pierre"
print(dogs)

# > Remove specific element
dogs.remove("Kiouze")
print(dogs)

# > Remove at end
print(dogs.pop())
print(dogs)

# > Insert at Index (second method)
dogs.insert(2, "Isimorn")
print(dogs)

# > Insert Slice
dogs[1:1] = ["Ludovictor", "Bazoukha"]
print(dogs)

# > Sorting array (modifies the original)
books = ["Dune", "Red Dragon", "The Stranger", "In Cold Blood", "Ubik"]
books.sort()
print(books)

# > Sorting array keys (modifies the original)
books = ["Dune", "Red Dragon", "the sound and the fury", "The Stranger", "In Cold Blood", "Ubik"]
books.sort(key=str.lower)
print(books)

# > Array Copy
booksCopy = books[:]
print(booksCopy)

# > Sorting array keys (doesn't modify the original)
print(sorted(books, key=str.lower))

# %%
# Tuples (/array methods) (ordored, unmutable)

names = ("Roger", "Syd")

print(names[0])
print(names.index("Roger"))

# %%
cat = {"name": "Gratouille", "age": 14, "eyes": "Green", "food": "ScoobySnacks"}
print(cat["name"])

# > Setter
cat["name"] = "Syd"
print(cat)

# > New item
cat["toy"] = "Aluminium ball"

# > Getter
print(cat.get("age"))

# > Getting default value for unset key
print(cat.get("color", "black"))

# > Removing specific key and return value
print(cat.pop("name"))
print(cat)

# > Removing last item
print(cat.popitem())
print(cat)

# > "In method"
print("color" in cat)

# > List of keys
print(cat.keys())
print(list(cat.keys()))

# > List of values
print(cat.values())
print(list(cat.values()))

# > List of pairs
print(cat.items())
print(list(cat.items()))

# > Deleting specific item
del cat["eyes"]
print(cat)

# > Copy dict.
catCopy = cat.copy()
print(catCopy)

# %%
# Sets (unordered, no duplicate)

set1 = {"Roger", "Syd"}
set2 = {"Roger", "Luna"}

intersect = set1 & set2
print(intersect)

union = set1 | set2
print(union)

diff = set1 - set2
print(diff)

superSet = set1 > set2
print(superSet)

# %%
# Default paramater function

def hello(name='my friend'):
    print('Hello ' + name)

hello()

# %%
items = [1, 2, 3, 4]
for item in items:
    print(item)

for item in range(15):
    print(item)

for item in enumerate(items):
    print(item)

items = [1, 2, 3, 4]
for item in items:
    if item == 2:
        continue
    print(item)

# break

# %%
class Animal:
    def walk(self):
        print('Walking...')

class Dog(Animal):
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print("woof!")

scooby = Dog('scooby', 38)
print(type(scooby))

print(scooby.name, scooby.age)

scooby.bark()
scooby.walk()

# %%
# import math
from math import sqrt

print(sqrt(4))

# %%
# > Lamba functions

lambda num : num * 2
lambda a, b : a * b

multiply = lambda a, b : a * b

print(multiply(2, 4))

# %%
from functools import reduce



numbers = [1, 2, 3, 4, 5, 6]

# def double(a):
#     return a * 2
# double = lambda a : a * 2

# result = map(double, numbers)
result = map(lambda a : a * 2, numbers)

print(list(result))



# def isEven(n):
#     return n % 2 == 0

result2 = filter(lambda n : n % 2 == 0, numbers)

print(list(result2))



expenses = [('Dinner', 80), ('Car repair', 120)]

sum = reduce(lambda a, b: a[1] + b[1], expenses)
print(sum)

# %%
# > Recusive function

def factorial(n):
    if n == 1: return 1
    return n * factorial(n-1)

print(factorial(18))

# %%
# > Decorators (using function in another context)

def logtime(func):
    def wrapper():
        print('before')
        val = func()
        print('after')
        return val
    return wrapper

@logtime
def hello():
    print('hello')

hello()

# %%
# > Docstrings + annotations

def increment(n):
    """Increment a number"""
    return n + 1

print(help(increment))



def increment(n: int) -> int:
    """Increment a number"""
    return n + 1

count: int = 0

# %%
# try:

# except <ERROR1>:
# except <ERROR2>:
# except:

# else:

# finally:


# > Standard Python exception
try:
    result = 2 / 0
except ZeroDivisionError:
    print('Cannot devide by zero!')
finally:
    result = 1

print(result)


# > Custom exception
try:
    raise Exception('An Error !')

except Exception as error:
    print(error)

# %%
# > List Compressions (simplfied map())

numbers = [1, 2, 3, 4]

numbers_power_2 = [n**2 for n in numbers]

print(numbers_power_2)

# %%
# > Operator Overloading

class Dog:
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def __gt__(self, other):
        return True if self.age > other.age else False
    
roger = Dog('Roger', 8)
syd = Dog('Syd', 7)

print(roger > syd)

# %%
import random

class Card:

    def __init__(self, suit, rank):

        self.suit = suit
        self.rank = rank

    def __str__(self):
        return f'{self.rank["rank"]} of {self.suit}'

class Deck:

    def __init__(self):

        self.cards = []

        suits = ['Spades', 'Clubs', 'Hearts', 'Diamonds']
        ranks = [
            {"rank" : "Ace", "value" : 11},
            {"rank" : "2", "value" : 2},
            {"rank" : "3", "value" : 3},
            {"rank" : "4", "value" : 4},
            {"rank" : "5", "value" : 5},
            {"rank" : "6", "value" : 6},
            {"rank" : "7", "value" : 7},
            {"rank" : "8", "value" : 8},
            {"rank" : "9", "value" : 9},
            {"rank" : "10", "value" : 10},
            {"rank" : "Jack", "value" : 10},
            {"rank" : "Queen", "value" : 10},
            {"rank" : "King", "value" : 10}
        ]

        for suit in suits:
            for rank in ranks:
                self.cards.append(Card(suit, rank))

    def shuffle(self):

        if len(self.cards) > 1:
            random.shuffle(self.cards)


    def deal(self, num):
        cards_dealt = []

        for x in range(num):
            
            if len(self.cards) > 0:

                card = self.cards.pop()
                cards_dealt.append(card)

        return cards_dealt
    
class Hand:

    def __init__(self, dealer = False):
        
        self.cards = []
        self.value = 0
        self.dealer = dealer

    def addCard(self, card_list):
        self.cards.extend(card_list)

    def calcValue(self):
        self.value = 0
        hasAce = False

        for card in self.cards:
            cardValue = int(card.rank['value'])
            self.value += cardValue

            if card.rank['rank'] == "Ace":
                hasAce = True

        if hasAce and self.value > 21:
            self.value -= 10
    
    def getValue(self):
        self.calcValue()
        return self.value
    
    def isBlackJack(self):
        return self.getValue() == 21
    
    def display(self, showDealerCards = False):
        print(f'{"Dealer's" if self.dealer else "Your"} Hand:')
        for index, card in enumerate(self.cards):
            if index == 0 and self.dealer and not showDealerCards \
            and not self.isBlackJack():
                print('Hidden')
            else:
                print(f'- {card}')

        if not self.dealer:
            print('Value:', self.getValue())

        print()

class Game:

    def play(self):
        gameNum = 0
        gamesToPlay = 0

        while gamesToPlay <= 0:
            try:
                gamesToPlay = int(input('How many games do you want to play ?'))
            except:
                print('You must enter a number')

        while gameNum < gamesToPlay:
            gameNum += 1

            deck = Deck()
            deck.shuffle()

            playerHand = Hand()
            dealerHand = Hand(dealer = True)

            for i in range(2):
                playerHand.addCard(deck.deal(1))
                dealerHand.addCard(deck.deal(1))

            print()
            print('*' * 30)
            print(f'Game {gameNum} of {gamesToPlay}')
            print('*' * 30)
            playerHand.display()
            dealerHand.display()

            if self.checkWinner(playerHand, dealerHand):
                continue

            choice = ""
            while playerHand.getValue() < 21 and choice not in ['s', 'stand']:
                choice = input('Please choose "Hit" or "Stand": ').lower()
                print()
                while choice not in ['h', 's', 'hit', 'stand']:
                    choice = input('Please enter "Hit" or "Stand" (or H/S)').lower()
                if choice in ['hit', 'h']:
                    playerHand.addCard(deck.deal(1))
                    playerHand.display()
            
            if self.checkWinner(playerHand, dealerHand):
                continue

            playerHandValue = playerHand.getValue()
            dealerHandValue = dealerHand.getValue()

            while dealerHandValue < 17:
                dealerHand.addCard(deck.deal(1))
                dealerHandValue = dealerHand.getValue()

            dealerHand.display(showDealerCards = True)

            if self.checkWinner(playerHand, dealerHand):
                continue

            print('Final Results')
            print('Your Hand', playerHandValue)
            print("Dealer's Hand", dealerHandValue)

            self.checkWinner(playerHand, dealerHand, True)

        print('\nThank you for playing !')

    def checkWinner(self, playerHand, dealerHand, gameOver = False):
        if not gameOver:
            if playerHand.getValue() > 21:
                print('You busted ! Dealer Wins !')
                return True
            elif dealerHand.getValue() > 21:
                print('Dealer busted ! You Win !')
                return True
            elif playerHand.isBlackJack() and dealerHand.isBlackJack():
                print('Both players have a BlackJack ! Tie !')
                return True
            elif playerHand.isBlackJack():
                print('You have BlackJack ! You Win !')
                return True
            elif dealerHand.isBlackJack():
                print('Dealer has BlackJack ! Dealer Wins !')
                return True
        else:
            if playerHand.getValue() > dealerHand.getValue():
                print('You Win !')
            elif playerHand.getValue() == dealerHand.getValue():
                print('Tie !')
            else:
                print('Dealer Wins !')
            return True
        return False

g = Game()
g.play()
