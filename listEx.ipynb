# %%
my_list = [10, 20, 30, 40, 50]

print(my_list[2])
print(len(my_list))
print(f'The list is {'empty' if len(my_list) < 0 else 'not empty'}')

# %%
my_list = [10, 20, 30, 40, 50]

my_list[1] = 200
my_list.append(600)
my_list.insert(2, 300)
my_list.remove(600)
my_list.pop(0)

print(my_list)

# %%
my_list = [10, 20, 30, 40, 50]

print(sum(my_list))
print(sum(my_list) / len(my_list))

# %%
list1 = [100, 200, 300, 400, 500]

list1.reverse()
# list1 = list1[::-1]

print(list1)

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]

numSqr = list(map(lambda el: el**2, numbers))
# numSqr = [x * x for x in numbers]

print(numSqr)

# %%
data = [8, 2, 15, 1, 9]
# max = data[0]
# min = data[0]

# for x in data:
#     if x > max:
#         max = x
#     if x < min:
#         min = x

maxNum = max(data)
minNum = min(data)

print(f'Max is {maxNum} \nMin is {minNum}')

# %%
sports = ['Cricket', 'Football', 'Hockey', 'Football', 'Tennis']

print(sports.count('Football'))

# %%
numbers = [5, 2, 8, 1, 9]

numbersSorted = sorted(numbers)
print(numbersSorted)

# %%
original_list = [10, 20, 30]

listCopy = original_list[:]
listCopy[0] = 'Tarte aux fraises'

print(original_list)
print(listCopy)

another_copy = list(original_list)
print(another_copy)

a_third_copy = original_list.copy()
print(a_third_copy)

# %%
list_a = [1, 2]
list_b = [3, 4]

# list_a.extend(list_b)
newList = list_a + list_b

# print(list_a)
print(newList)

# %%
list1 = ["Mike", "", "Emma", "Kelly", "", "Brad"]

res_list = list(filter(lambda el: el, list1))
print(res_list)
