# %%
fruits = {'apple', 'banana', 'mango', 'orange'}

fruits.add('grape')
fruits.remove('banana')
fruits.discard('mango')

print(fruits)

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

union = set1 | set2
print(union)

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

intersect = set1 & set2
print(intersect)

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

diff = set1 - set2
print(diff)

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

symDiff = set1.symmetric_difference(set2)
print(symDiff)

# %%
sample_set = {"Yellow", "Orange", "Black"}
sample_list = ["Blue", "Green", "Red"]

sample_set.update(sample_list)
print(sample_set)

# %%
set1 = {10, 20, 30}
set2 = {20, 40, 50}

set1.difference_update(set2)
print(set1)

# %%
set1 = {10, 20, 30, 40, 50}

set1.difference_update({40, 50})
print(set1)

# %%
subset_set = {10, 20}
main_set = {10, 20, 30, 40}

print(subset_set.issubset(main_set))

# %%
set1 = {10, 20}
set2 = {10, 20, 30, 40}

print(set2.issuperset(set1))

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {60, 70, 80, 90, 10}

if not set1.isdisjoint(set2):
    set3 = set1.intersection(set2)

print(set3)

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

set1.symmetric_difference_update(set2)
print(set1)

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

set1.intersection_update(set2)
print(set1)

# %%
list1 = [10, 20, 30, 40]
list2 = [30, 40, 50, 60]

linkSet = set(list1) & set(list2)
print(linkSet)

# %%
my_list = [10, 20, 30]

freeze = frozenset(my_list)
print(freeze)

# %%
sentence = "dog is a simple animal dogs is selfless animal"

words = sentence.split()
counter = len(set(words))

print(counter)
